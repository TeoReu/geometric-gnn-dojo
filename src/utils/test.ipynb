# %%
from src.utils.rewire_utils import n_hop_plus_0_hop, new_dataset
from src.utils.plot_utils import plot_2d
from src.utils.other import create_kchains

k = 5
dataset = create_kchains(k=k)

new_dataset = new_dataset(dataset, "k0hop", 0.25)
for data in new_dataset :
    plot_2d(data, lim=5*k)

print(new_dataset)
# Out:
# [Data(edge_index=[2, 19], y=[1], pos=[7, 3], atoms=[7]), Data(edge_index=[2, 20], y=[1], pos=[7, 3], atoms=[7])]
